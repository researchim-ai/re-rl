# %%
# %% [markdown]
# # Исследование математических задач с настраиваемой детализацией
# 
# В этом ноутбуке мы генерируем несколько типов математических задач с разными значениями параметра `detail_level`.
# 
# Для каждой задачи выводятся:
# - Описание задачи (problem)
# - Промт (prompt)
# - Пошаговое решение (solution_steps)
# - Итоговый ответ (final_answer)
# - LaTeX‑обёртка решения
# 
# Это позволяет исследовать, как изменение числа промежуточных шагов влияет на вывод решения, и как можно настраивать генерацию цепочки рассуждений.

# %% [code]
# Импорт необходимых классов из библиотеки re‑rl
from re_rl.tasks.linear_task import LinearTask
from re_rl.tasks.quadratic_task import QuadraticTask
from re_rl.tasks.cubic_task import CubicTask
from re_rl.tasks.exponential_task import ExponentialTask
from re_rl.tasks.logarithmic_task import LogarithmicTask
from re_rl.tasks.calculus_task import CalculusTask
from re_rl.tasks.system_linear_task import SystemLinearTask
from re_rl.tasks.factory import MathTaskFactory

# %% [code]
def explore_task(task, task_name):
    result = task.get_result()
    print("-----------------------------------------------------")
    print(f"{task_name} (Language: {task.language}, detail_level: {task.detail_level})")
    print("Постановка задачи:")
    print(result["problem"])
    print("\nПромт:")
    print(result["prompt"])
    print("\nПошаговое решение:")
    for step in result["solution_steps"]:
        print("  ", step)
    print("\nИтоговый ответ:")
    print(result["final_answer"])
    print("\nLaTeX-обёртка решения:")
    print(task.generate_latex_solution())
    print("-----------------------------------------------------\n")

# %% [markdown]
# ## Линейное уравнение
# Пример: 2x + 3 = 7 с разными уровнями детализации.

# %% [code]
for dl in [1, 2, 3, 4]:
    task = LinearTask(2, 3, 7, language="ru", detail_level=dl)
    explore_task(task, "Линейное уравнение")

# %% [markdown]
# ## Квадратное уравнение
# Пример: x² - 5x + 6 = 0 (корни 2 и 3).

# %% [code]
for dl in [2, 3, 4]:
    task = QuadraticTask(1, -5, 6, language="ru", detail_level=dl)
    explore_task(task, "Квадратное уравнение")

# %% [markdown]
# ## Кубическое уравнение
# Пример: x³ - 6x² + 11x - 6 = 0 (корни 1, 2, 3).

# %% [code]
for dl in [2, 3, 4]:
    task = CubicTask(1, -6, 11, -6, language="ru", detail_level=dl)
    explore_task(task, "Кубическое уравнение")

# %% [markdown]
# ## Экспоненциальное уравнение
# Пример: 2*exp(x) + 1 = 5, решение: x = ln(2).

# %% [code]
for dl in [2, 3, 4]:
    task = ExponentialTask(2, 1, 1, 5, language="en", detail_level=dl)
    explore_task(task, "Exponential Equation")

# %% [markdown]
# ## Логарифмическое уравнение
# Пример: 2*log(3*x) + 1 = 5, решение: x = exp((5-1)/2)/3.

# %% [code]
for dl in [2, 3, 4]:
    task = LogarithmicTask(2, 3, 1, 5, language="ru", detail_level=dl)
    explore_task(task, "Логарифмическое уравнение")

# %% [markdown]
# ## Задача по анализу (Calculus)
# Здесь генерируются задачи на дифференцирование и интегрирование полиномиальных функций.

# %% [code]
for task_type in ["differentiation", "integration"]:
    for dl in [2, 3, 4]:
        task = CalculusTask.generate_random_task(task_type=task_type, language="en", detail_level=dl)
        explore_task(task, f"Calculus Task ({task_type})")

# %% [markdown]
# ## Система линейных уравнений
# Пример: система 2x + y = 5, x + 2y = 4.

# %% [code]
# Зададим матрицу системы
matrix = [
    [2, 1, 5],
    [1, 2, 4]
]
for dl in [2, 3, 4]:
    task = SystemLinearTask(matrix, language="ru", detail_level=dl)
    explore_task(task, "Система линейных уравнений")

# %% [markdown]
# ## Фабрика случайных задач
# Использование фабрики для генерации случайной задачи из разных категорий (math, calculus, graph).

# %% [code]
for i in range(3):
    task = MathTaskFactory.generate_random_task(only_valid=True, language="ru", detail_level=3)
    explore_task(task, f"Случайная задача {i+1}")
# Out:
# -----------------------------------------------------
# Линейное уравнение (Language: ru, detail_level: 1)
# Постановка задачи:
# Решите линейное уравнение: 2x + 3 = 7
#
# Промт:
# Задача: Решите линейное уравнение: 2x + 3 = 7
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.
#
# Итоговый ответ:
# 2
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Линейное уравнение (Language: ru, detail_level: 2)
# Постановка задачи:
# Решите линейное уравнение: 2x + 3 = 7
#
# Промт:
# Задача: Решите линейное уравнение: 2x + 3 = 7
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.
#    Шаг 2: Вычисляем правую часть: 7 - 3 = 4.
#
# Итоговый ответ:
# 2
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.} \\
# \text{Шаг 2: Вычисляем правую часть: 7 - 3 = 4.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Линейное уравнение (Language: ru, detail_level: 3)
# Постановка задачи:
# Решите линейное уравнение: 2x + 3 = 7
#
# Промт:
# Задача: Решите линейное уравнение: 2x + 3 = 7
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.
#    Шаг 2: Вычисляем правую часть: 7 - 3 = 4.
#    Шаг 3: Делим обе части на 2: x = 4 / 2 = 2.
#
# Итоговый ответ:
# 2
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.} \\
# \text{Шаг 2: Вычисляем правую часть: 7 - 3 = 4.} \\
# \text{Шаг 3: Делим обе части на 2: x = 4 / 2 = 2.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Линейное уравнение (Language: ru, detail_level: 4)
# Постановка задачи:
# Решите линейное уравнение: 2x + 3 = 7
#
# Промт:
# Задача: Решите линейное уравнение: 2x + 3 = 7
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.
#    Шаг 2: Вычисляем правую часть: 7 - 3 = 4.
#    Вычисляем отношение: 4 / 2
#    Получаем x = 2
#    Шаг 3: Делим обе части на 2: x = 4 / 2 = 2.
#
# Итоговый ответ:
# 2
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение: 2⋅x + 3 = 7.} \\
# \text{Шаг 2: Вычисляем правую часть: 7 - 3 = 4.} \\
# \text{Вычисляем отношение: 4 / 2} \\
# \text{Получаем x = 2} \\
# \text{Шаг 3: Делим обе части на 2: x = 4 / 2 = 2.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Квадратное уравнение (Language: ru, detail_level: 2)
# Постановка задачи:
# Решите квадратное уравнение:  2
# x  - 5⋅x + 6 = 0
#
# Промт:
# Задача: Решите квадратное уравнение:  2
# x  - 5⋅x + 6 = 0
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение:  2
# x  - 5⋅x + 6 = 0.
#    Шаг 2: Вычисляем дискриминант: D = -5² - 4*1*6 = 1.
#    Шаг 3: Находим корни уравнения: x = [2, 3].
#
# Итоговый ответ:
# [2, 3]
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение:  2
# x  - 5⋅x + 6 = 0.} \\
# \text{Шаг 2: Вычисляем дискриминант: D = -5² - 4*1*6 = 1.} \\
# \text{Шаг 3: Находим корни уравнения: x = [2, 3].}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Квадратное уравнение (Language: ru, detail_level: 3)
# Постановка задачи:
# Решите квадратное уравнение:  2
# x  - 5⋅x + 6 = 0
#
# Промт:
# Задача: Решите квадратное уравнение:  2
# x  - 5⋅x + 6 = 0
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение:  2
# x  - 5⋅x + 6 = 0.
#    Шаг 2: Вычисляем дискриминант: D = -5² - 4*1*6 = 1.
#    Шаг 3: Находим корни уравнения: x = [2, 3].
#
# Итоговый ответ:
# [2, 3]
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение:  2
# x  - 5⋅x + 6 = 0.} \\
# \text{Шаг 2: Вычисляем дискриминант: D = -5² - 4*1*6 = 1.} \\
# \text{Шаг 3: Находим корни уравнения: x = [2, 3].}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Квадратное уравнение (Language: ru, detail_level: 4)
# Постановка задачи:
# Решите квадратное уравнение:  2
# x  - 5⋅x + 6 = 0
#
# Промт:
# Задача: Решите квадратное уравнение:  2
# x  - 5⋅x + 6 = 0
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение:  2
# x  - 5⋅x + 6 = 0.
#    Шаг 2: Вычисляем дискриминант: D = -5² - 4*1*6 = 1.
#    Шаг 3: Находим корни уравнения: x = [2, 3].
#
# Итоговый ответ:
# [2, 3]
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение:  2
# x  - 5⋅x + 6 = 0.} \\
# \text{Шаг 2: Вычисляем дискриминант: D = -5² - 4*1*6 = 1.} \\
# \text{Шаг 3: Находим корни уравнения: x = [2, 3].}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Кубическое уравнение (Language: ru, detail_level: 2)
# Постановка задачи:
# Решите кубическое уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0
#
# Промт:
# Задача: Решите кубическое уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0.
#    Шаг 2: Находим корни уравнения: x = [1, 2, 3].
#
# Итоговый ответ:
# [1, 2, 3]
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0.} \\
# \text{Шаг 2: Находим корни уравнения: x = [1, 2, 3].}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Кубическое уравнение (Language: ru, detail_level: 3)
# Постановка задачи:
# Решите кубическое уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0
#
# Промт:
# Задача: Решите кубическое уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0.
#    Шаг 2: Находим корни уравнения: x = [1, 2, 3].
#
# Итоговый ответ:
# [1, 2, 3]
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0.} \\
# \text{Шаг 2: Находим корни уравнения: x = [1, 2, 3].}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Кубическое уравнение (Language: ru, detail_level: 4)
# Постановка задачи:
# Решите кубическое уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0
#
# Промт:
# Задача: Решите кубическое уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0.
#    Шаг 2: Находим корни уравнения: x = [1, 2, 3].
#
# Итоговый ответ:
# [1, 2, 3]
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение:  3      2
# x  - 6⋅x  + 11⋅x - 6 = 0.} \\
# \text{Шаг 2: Находим корни уравнения: x = [1, 2, 3].}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Exponential Equation (Language: en, detail_level: 2)
# Постановка задачи:
# Solve the exponential equation: 2exp(*x) + 1 = 5
#
# Промт:
# Task: Solve the exponential equation: 2exp(*x) + 1 = 5
#
# Пошаговое решение:
#    Step 1: Write the equation:    x
# 2⋅ℯ  + 1 = 5.
#    Step 2: Transfer 1 to the right side: 2*exp(1*x) = 5 - 1.
#    Step 3: Divide both sides by 2: exp(1*x) = 4 / 2.
#    Step 4: Apply the natural logarithm: x = log(2.0) / 1 = 0.693147180559945.
#
# Итоговый ответ:
# 0.693147180559945
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the equation:    x
# 2⋅ℯ  + 1 = 5.} \\
# \text{Step 2: Transfer 1 to the right side: 2*exp(1*x) = 5 - 1.} \\
# \text{Step 3: Divide both sides by 2: exp(1*x) = 4 / 2.} \\
# \text{Step 4: Apply the natural logarithm: x = log(2.0) / 1 = 0.693147180559945.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Exponential Equation (Language: en, detail_level: 3)
# Постановка задачи:
# Solve the exponential equation: 2exp(*x) + 1 = 5
#
# Промт:
# Task: Solve the exponential equation: 2exp(*x) + 1 = 5
#
# Пошаговое решение:
#    Step 1: Write the equation:    x
# 2⋅ℯ  + 1 = 5.
#    Step 2: Transfer 1 to the right side: 2*exp(1*x) = 5 - 1.
#    Step 3: Divide both sides by 2: exp(1*x) = 4 / 2.
#    Step 4: Apply the natural logarithm: x = log(2.0) / 1 = 0.693147180559945.
#
# Итоговый ответ:
# 0.693147180559945
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the equation:    x
# 2⋅ℯ  + 1 = 5.} \\
# \text{Step 2: Transfer 1 to the right side: 2*exp(1*x) = 5 - 1.} \\
# \text{Step 3: Divide both sides by 2: exp(1*x) = 4 / 2.} \\
# \text{Step 4: Apply the natural logarithm: x = log(2.0) / 1 = 0.693147180559945.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Exponential Equation (Language: en, detail_level: 4)
# Постановка задачи:
# Solve the exponential equation: 2exp(*x) + 1 = 5
#
# Промт:
# Task: Solve the exponential equation: 2exp(*x) + 1 = 5
#
# Пошаговое решение:
#    Step 1: Write the equation:    x
# 2⋅ℯ  + 1 = 5.
#    Step 2: Transfer 1 to the right side: 2*exp(1*x) = 5 - 1.
#    Step 3: Divide both sides by 2: exp(1*x) = 4 / 2.
#    Вычисляем log(2.0)
#    Делим на 1: получаем 0.693147180559945
#    Step 4: Apply the natural logarithm: x = log(2.0) / 1 = 0.693147180559945.
#
# Итоговый ответ:
# 0.693147180559945
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the equation:    x
# 2⋅ℯ  + 1 = 5.} \\
# \text{Step 2: Transfer 1 to the right side: 2*exp(1*x) = 5 - 1.} \\
# \text{Step 3: Divide both sides by 2: exp(1*x) = 4 / 2.} \\
# \text{Вычисляем log(2.0)} \\
# \text{Делим на 1: получаем 0.693147180559945} \\
# \text{Step 4: Apply the natural logarithm: x = log(2.0) / 1 = 0.693147180559945.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Логарифмическое уравнение (Language: ru, detail_level: 2)
# Постановка задачи:
# Решите логарифмическое уравнение: 2log(3*x) + 1 = 5
#
# Промт:
# Задача: Решите логарифмическое уравнение: 2log(3*x) + 1 = 5
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение: 2⋅log(3⋅x) + 1 = 5.
#    Шаг 2: Переносим 1 на правую сторону: 2*log(3*x) = 5 - 1.
#    Шаг 3: Делим обе части на 2: log(3*x) = (5 - 1) / 2.
#    Шаг 4: Вычисляем x = exp((5 - 1)/2)/3 = 2.46301869964355.
#
# Итоговый ответ:
# 2.46301869964355
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение: 2⋅log(3⋅x) + 1 = 5.} \\
# \text{Шаг 2: Переносим 1 на правую сторону: 2*log(3*x) = 5 - 1.} \\
# \text{Шаг 3: Делим обе части на 2: log(3*x) = (5 - 1) / 2.} \\
# \text{Шаг 4: Вычисляем x = exp((5 - 1)/2)/3 = 2.46301869964355.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Логарифмическое уравнение (Language: ru, detail_level: 3)
# Постановка задачи:
# Решите логарифмическое уравнение: 2log(3*x) + 1 = 5
#
# Промт:
# Задача: Решите логарифмическое уравнение: 2log(3*x) + 1 = 5
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение: 2⋅log(3⋅x) + 1 = 5.
#    Шаг 2: Переносим 1 на правую сторону: 2*log(3*x) = 5 - 1.
#    Шаг 3: Делим обе части на 2: log(3*x) = (5 - 1) / 2.
#    Шаг 4: Вычисляем x = exp((5 - 1)/2)/3 = 2.46301869964355.
#
# Итоговый ответ:
# 2.46301869964355
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение: 2⋅log(3⋅x) + 1 = 5.} \\
# \text{Шаг 2: Переносим 1 на правую сторону: 2*log(3*x) = 5 - 1.} \\
# \text{Шаг 3: Делим обе части на 2: log(3*x) = (5 - 1) / 2.} \\
# \text{Шаг 4: Вычисляем x = exp((5 - 1)/2)/3 = 2.46301869964355.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Логарифмическое уравнение (Language: ru, detail_level: 4)
# Постановка задачи:
# Решите логарифмическое уравнение: 2log(3*x) + 1 = 5
#
# Промт:
# Задача: Решите логарифмическое уравнение: 2log(3*x) + 1 = 5
#
# Пошаговое решение:
#    Шаг 1: Запишем уравнение: 2⋅log(3⋅x) + 1 = 5.
#    Шаг 2: Переносим 1 на правую сторону: 2*log(3*x) = 5 - 1.
#    Шаг 3: Делим обе части на 2: log(3*x) = (5 - 1) / 2.
#    Шаг 4: Вычисляем x = exp((5 - 1)/2)/3 = 2.46301869964355.
#
# Итоговый ответ:
# 2.46301869964355
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем уравнение: 2⋅log(3⋅x) + 1 = 5.} \\
# \text{Шаг 2: Переносим 1 на правую сторону: 2*log(3*x) = 5 - 1.} \\
# \text{Шаг 3: Делим обе части на 2: log(3*x) = (5 - 1) / 2.} \\
# \text{Шаг 4: Вычисляем x = exp((5 - 1)/2)/3 = 2.46301869964355.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Calculus Task (differentiation) (Language: en, detail_level: 2)
# Постановка задачи:
# Find the производную of the function f(x) =    2
# - x  - 4⋅x + 4.
#
# Промт:
# Task: Find the производную of the function f(x) =    2
# - x  - 4⋅x + 4.
#
# Пошаговое решение:
#    Step 1: Write the function: f(x) =    2
# - x  - 4⋅x + 4.
#    Step 2: Compute the производную: -2⋅x - 4.
#
# Итоговый ответ:
# -2⋅x - 4
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the function: f(x) =    2
# - x  - 4⋅x + 4.} \\
# \text{Step 2: Compute the производную: -2⋅x - 4.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Calculus Task (differentiation) (Language: en, detail_level: 3)
# Постановка задачи:
# Find the производную of the function f(x) =  3    2
# x  - x  - 5⋅x - 1.
#
# Промт:
# Task: Find the производную of the function f(x) =  3    2
# x  - x  - 5⋅x - 1.
#
# Пошаговое решение:
#    Step 1: Write the function: f(x) =  3    2
# x  - x  - 5⋅x - 1.
#    Step 2: Compute the производную:    2
# 3⋅x  - 2⋅x - 5.
#
# Итоговый ответ:
#    2
# 3⋅x  - 2⋅x - 5
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the function: f(x) =  3    2
# x  - x  - 5⋅x - 1.} \\
# \text{Step 2: Compute the производную:    2
# 3⋅x  - 2⋅x - 5.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Calculus Task (differentiation) (Language: en, detail_level: 4)
# Постановка задачи:
# Find the производную of the function f(x) =    3    2
# 4⋅x  + x  + x + 1.
#
# Промт:
# Task: Find the производную of the function f(x) =    3    2
# 4⋅x  + x  + x + 1.
#
# Пошаговое решение:
#    Step 1: Write the function: f(x) =    3    2
# 4⋅x  + x  + x + 1.
#    Step 2: Compute the производную:     2
# 12⋅x  + 2⋅x + 1.
#
# Итоговый ответ:
#     2
# 12⋅x  + 2⋅x + 1
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the function: f(x) =    3    2
# 4⋅x  + x  + x + 1.} \\
# \text{Step 2: Compute the производную:     2
# 12⋅x  + 2⋅x + 1.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Calculus Task (integration) (Language: en, detail_level: 2)
# Постановка задачи:
# Find the неопределённый интеграл of the function f(x) =      2
# - 2⋅x  + 3⋅x + 5.
#
# Промт:
# Task: Find the неопределённый интеграл of the function f(x) =      2
# - 2⋅x  + 3⋅x + 5.
#
# Пошаговое решение:
#    Step 1: Write the function: f(x) =      2
# - 2⋅x  + 3⋅x + 5.
#    Step 2: Compute the неопределённый интеграл:      3      2
#   2⋅x    3⋅x
# - ──── + ──── + 5⋅x
#    3      2         + C.
#
# Итоговый ответ:
#      3      2
#   2⋅x    3⋅x
# - ──── + ──── + 5⋅x
#    3      2         + C
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the function: f(x) =      2
# - 2⋅x  + 3⋅x + 5.} \\
# \text{Step 2: Compute the неопределённый интеграл:      3      2
#   2⋅x    3⋅x
# - ──── + ──── + 5⋅x
#    3      2         + C.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Calculus Task (integration) (Language: en, detail_level: 3)
# Постановка задачи:
# Find the неопределённый интеграл of the function f(x) =    2
# 5⋅x  + 3.
#
# Промт:
# Task: Find the неопределённый интеграл of the function f(x) =    2
# 5⋅x  + 3.
#
# Пошаговое решение:
#    Step 1: Write the function: f(x) =    2
# 5⋅x  + 3.
#    Step 2: Compute the неопределённый интеграл:    3
# 5⋅x
# ──── + 3⋅x
#  3         + C.
#
# Итоговый ответ:
#    3
# 5⋅x
# ──── + 3⋅x
#  3         + C
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the function: f(x) =    2
# 5⋅x  + 3.} \\
# \text{Step 2: Compute the неопределённый интеграл:    3
# 5⋅x
# ──── + 3⋅x
#  3         + C.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Calculus Task (integration) (Language: en, detail_level: 4)
# Постановка задачи:
# Find the неопределённый интеграл of the function f(x) =    3      2
# 2⋅x  + 4⋅x  - 2⋅x + 1.
#
# Промт:
# Task: Find the неопределённый интеграл of the function f(x) =    3      2
# 2⋅x  + 4⋅x  - 2⋅x + 1.
#
# Пошаговое решение:
#    Step 1: Write the function: f(x) =    3      2
# 2⋅x  + 4⋅x  - 2⋅x + 1.
#    Step 2: Compute the неопределённый интеграл:  4      3
# x    4⋅x     2
# ── + ──── - x  + x
# 2     3            + C.
#
# Итоговый ответ:
#  4      3
# x    4⋅x     2
# ── + ──── - x  + x
# 2     3            + C
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Step 1: Write the function: f(x) =    3      2
# 2⋅x  + 4⋅x  - 2⋅x + 1.} \\
# \text{Step 2: Compute the неопределённый интеграл:  4      3
# x    4⋅x     2
# ── + ──── - x  + x
# 2     3            + C.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Система линейных уравнений (Language: ru, detail_level: 3)
# Постановка задачи:
# Решите систему уравнений:
# 2.0x1 + x2 = 5.0
# x1 + 2.0x2 = 4.0
#
# Промт:
# Задача: Решите систему уравнений:
# 2.0x1 + x2 = 5.0
# x1 + 2.0x2 = 4.0
#
# Пошаговое решение:
#    Шаг 1: Вычисляем главный определитель системы: det(A) = 3.00
#    Шаг 2: Заменяем 1-й столбец и вычисляем det(A_1) = 6.00
#    Шаг 3: x1 = det(A_1) / det(A) = 2.00
#    Шаг 4: Заменяем 2-й столбец и вычисляем det(A_2) = 3.00
#    Шаг 5: x2 = det(A_2) / det(A) = 1.00
#
# Итоговый ответ:
# x1 = 2.00, x2 = 1.00
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Вычисляем главный определитель системы: det(A) = 3.00} \\
# \text{Шаг 2: Заменяем 1-й столбец и вычисляем det(A\_1) = 6.00} \\
# \text{Шаг 3: x1 = det(A\_1) / det(A) = 2.00} \\
# \text{Шаг 4: Заменяем 2-й столбец и вычисляем det(A\_2) = 3.00} \\
# \text{Шаг 5: x2 = det(A\_2) / det(A) = 1.00}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Система линейных уравнений (Language: ru, detail_level: 3)
# Постановка задачи:
# Решите систему уравнений:
# 2.0x1 + x2 = 5.0
# x1 + 2.0x2 = 4.0
#
# Промт:
# Задача: Решите систему уравнений:
# 2.0x1 + x2 = 5.0
# x1 + 2.0x2 = 4.0
#
# Пошаговое решение:
#    Шаг 1: Вычисляем главный определитель системы: det(A) = 3.00
#    Шаг 2: Заменяем 1-й столбец и вычисляем det(A_1) = 6.00
#    Шаг 3: x1 = det(A_1) / det(A) = 2.00
#    Шаг 4: Заменяем 2-й столбец и вычисляем det(A_2) = 3.00
#    Шаг 5: x2 = det(A_2) / det(A) = 1.00
#
# Итоговый ответ:
# x1 = 2.00, x2 = 1.00
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Вычисляем главный определитель системы: det(A) = 3.00} \\
# \text{Шаг 2: Заменяем 1-й столбец и вычисляем det(A\_1) = 6.00} \\
# \text{Шаг 3: x1 = det(A\_1) / det(A) = 2.00} \\
# \text{Шаг 4: Заменяем 2-й столбец и вычисляем det(A\_2) = 3.00} \\
# \text{Шаг 5: x2 = det(A\_2) / det(A) = 1.00}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Система линейных уравнений (Language: ru, detail_level: 3)
# Постановка задачи:
# Решите систему уравнений:
# 2.0x1 + x2 = 5.0
# x1 + 2.0x2 = 4.0
#
# Промт:
# Задача: Решите систему уравнений:
# 2.0x1 + x2 = 5.0
# x1 + 2.0x2 = 4.0
#
# Пошаговое решение:
#    Шаг 1: Вычисляем главный определитель системы: det(A) = 3.00
#    Шаг 2: Заменяем 1-й столбец и вычисляем det(A_1) = 6.00
#    Шаг 3: x1 = det(A_1) / det(A) = 2.00
#    Шаг 4: Заменяем 2-й столбец и вычисляем det(A_2) = 3.00
#    Шаг 5: x2 = det(A_2) / det(A) = 1.00
#
# Итоговый ответ:
# x1 = 2.00, x2 = 1.00
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Вычисляем главный определитель системы: det(A) = 3.00} \\
# \text{Шаг 2: Заменяем 1-й столбец и вычисляем det(A\_1) = 6.00} \\
# \text{Шаг 3: x1 = det(A\_1) / det(A) = 2.00} \\
# \text{Шаг 4: Заменяем 2-й столбец и вычисляем det(A\_2) = 3.00} \\
# \text{Шаг 5: x2 = det(A\_2) / det(A) = 1.00}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Случайная задача 1 (Language: ru, detail_level: 3)
# Постановка задачи:
# Найди минимальное остовное дерево данного графа.
#
# Промт:
# Задача: Найди минимальное остовное дерево данного графа.
#
# Пошаговое решение:
#    Шаг 2: Решаем задачу: Найденное минимальное остовное дерево: [(0, 8, {'weight': 1}), (0, 1, {'weight': 5}), (1, 5, {'weight': 3}), (1, 3, {'weight': 4}), (2, 9, {'weight': 1}), (2, 7, {'weight': 2}), (2, 4, {'weight': 4}), (2, 6, {'weight': 7}), (4, 5, {'weight': 1})]..
#
# Итоговый ответ:
# [(0, 8, {'weight': 1}), (0, 1, {'weight': 5}), (1, 5, {'weight': 3}), (1, 3, {'weight': 4}), (2, 9, {'weight': 1}), (2, 7, {'weight': 2}), (2, 4, {'weight': 4}), (2, 6, {'weight': 7}), (4, 5, {'weight': 1})]
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 2: Решаем задачу: Найденное минимальное остовное дерево: [(0, 8, {'weight': 1}), (0, 1, {'weight': 5}), (1, 5, {'weight': 3}), (1, 3, {'weight': 4}), (2, 9, {'weight': 1}), (2, 7, {'weight': 2}), (2, 4, {'weight': 4}), (2, 6, {'weight': 7}), (4, 5, {'weight': 1})]..}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Случайная задача 2 (Language: ru, detail_level: 3)
# Постановка задачи:
# Найди неопределённый интеграл функции f(x) =    2
# 5⋅x  - 5⋅x + 1.
#
# Промт:
# Задача: Найди неопределённый интеграл функции f(x) =    2
# 5⋅x  - 5⋅x + 1.
#
# Пошаговое решение:
#    Шаг 1: Запишем функцию: f(x) =    2
# 5⋅x  - 5⋅x + 1.
#    Шаг 2: Вычисляем неопределённый интеграл:    3      2
# 5⋅x    5⋅x
# ──── - ──── + x
#  3      2       + C.
#
# Итоговый ответ:
#    3      2
# 5⋅x    5⋅x
# ──── - ──── + x
#  3      2       + C
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 1: Запишем функцию: f(x) =    2
# 5⋅x  - 5⋅x + 1.} \\
# \text{Шаг 2: Вычисляем неопределённый интеграл:    3      2
# 5⋅x    5⋅x
# ──── - ──── + x
#  3      2       + C.}\end{align*}
# -----------------------------------------------------
#
# -----------------------------------------------------
# Случайная задача 3 (Language: ru, detail_level: 3)
# Постановка задачи:
# Найди средний коэффициент кластеризации данного графа.
#
# Промт:
# Задача: Найди средний коэффициент кластеризации данного графа.
#
# Пошаговое решение:
#    Шаг 2: Решаем задачу: Средний коэффициент кластеризации: 0.539047619047619..
#
# Итоговый ответ:
# 0.539047619047619
#
# LaTeX-обёртка решения:
# \begin{align*}\text{Шаг 2: Решаем задачу: Средний коэффициент кластеризации: 0.539047619047619..}\end{align*}
# -----------------------------------------------------

# %%
from re_rl.tasks.graph_task import GraphTask

# Генерируем одну случайную графовую задачу
task = GraphTask.generate_random_task(only_valid=True, num_nodes=10, edge_prob=0.5)
result = task.get_result()

print("Постановка задачи:")
print(result["problem"])
print("\nПромт:")
print(result["prompt"])
print("\nПошаговое решение:")
for step in result["solution_steps"]:
    print("  ", step)
print("\nИтоговый ответ:")
print(result["final_answer"])

# %% [code]
# Генерируем набор случайных графовых задач для быстрого исследования
num_tasks = 10
tasks = []
for _ in range(num_tasks):
    task = GraphTask.generate_random_task(only_valid=True, num_nodes=10, edge_prob=0.5)
    tasks.append(task.get_result())

print("Сгенерировано задач:", len(tasks))
for i, res in enumerate(tasks):
    print(f"\n--- Задача {i+1} ---")
    print("Постановка задачи:", res["problem"])
    print("Итоговый ответ:", res["final_answer"])
# Out:
# Постановка задачи:
# Найди минимальное остовное дерево данного графа.
#
# Промт:
# Задача: Найди минимальное остовное дерево данного графа.
#
# Пошаговое решение:
#    Шаг 2: Решаем задачу: Найденное минимальное остовное дерево: [(0, 5, {'weight': 1}), (0, 6, {'weight': 1}), (0, 3, {'weight': 3}), (0, 4, {'weight': 4}), (0, 2, {'weight': 5}), (1, 2, {'weight': 1}), (1, 9, {'weight': 4}), (4, 8, {'weight': 2}), (7, 8, {'weight': 4})]..
#
# Итоговый ответ:
# [(0, 5, {'weight': 1}), (0, 6, {'weight': 1}), (0, 3, {'weight': 3}), (0, 4, {'weight': 4}), (0, 2, {'weight': 5}), (1, 2, {'weight': 1}), (1, 9, {'weight': 4}), (4, 8, {'weight': 2}), (7, 8, {'weight': 4})]
# Сгенерировано задач: 10
#
# --- Задача 1 ---
# Постановка задачи: Найди средний коэффициент кластеризации данного графа.
# Итоговый ответ: 0.4947619047619048
#
# --- Задача 2 ---
# Постановка задачи: Найди средний коэффициент кластеризации данного графа.
# Итоговый ответ: 0.6261111111111111
#
# --- Задача 3 ---
# Постановка задачи: Найди средний коэффициент кластеризации данного графа.
# Итоговый ответ: 0.4947619047619048
#
# --- Задача 4 ---
# Постановка задачи: Найди средний коэффициент кластеризации данного графа.
# Итоговый ответ: 0.53
#
# --- Задача 5 ---
# Постановка задачи: Найди кратчайший путь между узлами 5 и 8.
# Итоговый ответ: [5, 1, 2, 8]
#
# --- Задача 6 ---
# Постановка задачи: Найди минимальное остовное дерево данного графа.
# Итоговый ответ: [(0, 3, {'weight': 5}), (1, 8, {'weight': 3}), (1, 3, {'weight': 4}), (1, 2, {'weight': 5}), (1, 4, {'weight': 7}), (1, 9, {'weight': 7}), (3, 7, {'weight': 1}), (3, 6, {'weight': 6}), (5, 9, {'weight': 9})]
#
# --- Задача 7 ---
# Постановка задачи: Найди минимальное остовное дерево данного графа.
# Итоговый ответ: [(0, 2, {'weight': 2}), (0, 6, {'weight': 2}), (0, 7, {'weight': 4}), (1, 5, {'weight': 4}), (2, 3, {'weight': 2}), (2, 4, {'weight': 4}), (2, 8, {'weight': 4}), (5, 9, {'weight': 2}), (8, 9, {'weight': 1})]
#
# --- Задача 8 ---
# Постановка задачи: Найди кратчайший путь между узлами 8 и 6.
# Итоговый ответ: [8, 6]
#
# --- Задача 9 ---
# Постановка задачи: Найди средний коэффициент кластеризации данного графа.
# Итоговый ответ: 0.3733333333333333
#
# --- Задача 10 ---
# Постановка задачи: Найди диаметр данного графа.
# Итоговый ответ: 3

# %%
from re_rl.tasks.calculus_task import CalculusTask

# Генерация задачи на дифференцирование
task_diff = CalculusTask.generate_random_task(task_type="differentiation")
result_diff = task_diff.get_result()
print("Дифференцирование:")
print("Постановка задачи:", result_diff["problem"])
for step in result_diff["solution_steps"]:
    print(step)
print("Итоговый ответ:", result_diff["final_answer"])

# Генерация задачи на интегрирование
task_int = CalculusTask.generate_random_task(task_type="integration")
result_int = task_int.get_result()
print("\nИнтегрирование:")
print("Постановка задачи:", result_int["problem"])
for step in result_int["solution_steps"]:
    print(step)
print("Итоговый ответ:", result_int["final_answer"])
# Out:
# Дифференцирование:
# Постановка задачи: Найди производную функции f(x) =  2
# x  - 2⋅x + 5.
# Шаг 1: Запишем функцию: f(x) =  2
# x  - 2⋅x + 5.
# Шаг 2: Вычисляем производную: 2⋅x - 2.
# Итоговый ответ: 2⋅x - 2
#
# Интегрирование:
# Постановка задачи: Найди неопределённый интеграл функции f(x) =    3    2
# - x  - x  - 4⋅x - 4.
# Шаг 1: Запишем функцию: f(x) =    3    2
# - x  - x  - 4⋅x - 4.
# Шаг 2: Вычисляем неопределённый интеграл:    4    3
#   x    x       2
# - ── - ── - 2⋅x  - 4⋅x
#   4    3               + C.
# Итоговый ответ:    4    3
#   x    x       2
# - ── - ── - 2⋅x  - 4⋅x
#   4    3               + C
